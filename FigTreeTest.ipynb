# %%
#!pip3 install cairosvg

# %%
from trees import *
from figtree import showtree
import operators as ops

tb = Treebank(default_op = ops.CONCAT)

# %%
t0 = tree("([S]([NP]([PN]True))([VP]([V]'saw')([NP]([NP]([Det]'the')([N]'dog'))([PP]([Prep]'with')([NP]([Det]'the')([N]'telescope'))))))", treebank=tb)

# %%
showtree(t0[0])

# %%
showtree(t0[1])

# %%
showtree(t0)

# %%
t0

# %%
from tempfile import TemporaryDirectory

# %%
ttt = TemporaryDirectory()
ttt.name
